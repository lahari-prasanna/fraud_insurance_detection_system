# %% [markdown]
# ## Import required libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Load the Dataset

# %%
df = pd.read_csv("01_Auto_Insurance_Fraud_Claims_Build_Test_Model_F01.csv")

df.head()
# Out:
#    Fraud_Ind Policy_Start_Date Policy_Expiry_Date Accident_Date  \
# 0          0         1/27/2025          7/28/2025      3/9/2025
# 1          0          6/1/2025         11/30/2025      6/4/2025
# 2          0         6/22/2025         12/21/2025      7/4/2025
# 3          0          1/2/2025           7/3/2025     1/27/2025
# 4          0        10/25/2024          4/25/2025    11/19/2024
#
#   Claim_Initiated_Date  Household_Num Driver_Num  Policy_Num Claim_Num  \
# 0             4/8/2025     4670185276   SW059585   355924169  DZW11767
# 1             7/5/2025     8526791677   ZO779075   848558311  CVG38057
# 2             7/6/2025     4618820582   LG406912   473829217  RUO86042
# 3            2/27/2025     3846198554   NJ146743   116719734  WOS87550
# 4           12/22/2024     9856770505   KX673536   481900450  ACJ85041
#
#   License_Plate  ... Commute_Discount Claims_Status Claim_Amount Model_Year  \
# 0      MGN62082  ...                1             1         3954       2022
# 1      WXK26533  ...                0             4        17917       2011
# 2      NNL54173  ...                0             3        13884       2015
# 3      THC81673  ...                0             3         4079       2015
# 4      NKY26268  ...                1             2         3671       2020
#
#          Make     Model   Color  Police_Report  Initial_Odometer  \
# 0  Volkswagen     Jetta     Red             No             87817
# 1      Toyota     Camry    Grey            Yes             22928
# 2        Audi        A6   Black             No             79831
# 3         BMW  3 Series   White             No            112017
# 4       Honda    Accord  Silver             No            101637
#
#    Odometer_At_Incident
# 0                 93539
# 1                 30075
# 2                 91252
# 3                117688
# 4                110535
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Basic data understanding

# %%
df.shape
# Out:
# (100000, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Fraud_Ind                100000 non-null  int64
#  1   Policy_Start_Date        100000 non-null  object
#  2   Policy_Expiry_Date       100000 non-null  object
#  3   Accident_Date            100000 non-null  object
#  4   Claim_Initiated_Date     100000 non-null  object
#  5   Household_Num            100000 non-null  int64
#  6   Driver_Num               100000 non-null  object
#  7   Policy_Num               100000 non-null  int64
#  8   Claim_Num                100000 non-null  object
#  9   License_Plate            100000 non-null  object
#  10  Drivers_License_Num      100000 non-null  object
#  11  Drivers_License_State    100000 non-null  object
#  12  DL_Expiry_Date           100000 non-null  object
#  13  Date_At_Current_Address  100000 non-null  object
#  14  Age                      100000 non-null  int64
#  15  Gender                   100000 non-null  object
#  16  Commute_Discount         100000 non-null  int64
#  17  Claims_Status            100000 non-null  int64
#  18  Claim_Amount             100000 non-null  int64
#  19  Model_Year               100000 non-null  int64
#  20  Make                     100000 non-null  object
#  21  Model                    100000 non-null  object
#  22  Color                    100000 non-null  object
#  23  Police_Report            100000 non-null  object
#  24  Initial_Odometer         100000 non-null  int64
#  25  Odometer_At_Incident     100000 non-null  int64
# dtypes: int64(10), object(16)
# memory usage: 19.8+ MB

# %%
df.describe(include='all')
# Out:
#             Fraud_Ind Policy_Start_Date Policy_Expiry_Date Accident_Date  \
# count   100000.000000            100000             100000        100000
# unique            NaN               365                365           571
# top               NaN         1/20/2025          7/21/2025      2/8/2025
# freq              NaN               326                326           328
# mean         0.074070               NaN                NaN           NaN
# std          0.261886               NaN                NaN           NaN
# min          0.000000               NaN                NaN           NaN
# 25%          0.000000               NaN                NaN           NaN
# 50%          0.000000               NaN                NaN           NaN
# 75%          0.000000               NaN                NaN           NaN
# max          1.000000               NaN                NaN           NaN
#
#        Claim_Initiated_Date  Household_Num Driver_Num    Policy_Num Claim_Num  \
# count                100000   1.000000e+05     100000  1.000000e+05    100000
# unique                  589            NaN      99992           NaN     99995
# top                4/4/2025            NaN   XL973668           NaN  JRB45308
# freq                    314            NaN          2           NaN         2
# mean                    NaN   5.511925e+09        NaN  5.480008e+08       NaN
# std                     NaN   2.594574e+09        NaN  2.602975e+08       NaN
# min                     NaN   1.000275e+09        NaN  1.000038e+08       NaN
# 25%                     NaN   3.269090e+09        NaN  3.224573e+08       NaN
# 50%                     NaN   5.525919e+09        NaN  5.474760e+08       NaN
# 75%                     NaN   7.752506e+09        NaN  7.738752e+08       NaN
# max                     NaN   9.999961e+09        NaN  9.999945e+08       NaN
#
#        License_Plate  ... Commute_Discount  Claims_Status  Claim_Amount  \
# count         100000  ...    100000.000000  100000.000000  100000.00000
# unique        100000  ...              NaN            NaN           NaN
# top         MGN62082  ...              NaN            NaN           NaN
# freq               1  ...              NaN            NaN           NaN
# mean             NaN  ...         0.502340       2.499660   13019.77444
# std              NaN  ...         0.499997       1.119389    6937.05472
# min              NaN  ...         0.000000       1.000000    1000.00000
# 25%              NaN  ...         0.000000       1.000000    6994.75000
# 50%              NaN  ...         1.000000       2.000000   13018.00000
# 75%              NaN  ...         1.000000       4.000000   19038.00000
# max              NaN  ...         1.000000       4.000000   25000.00000
#
#            Model_Year    Make   Model   Color  Police_Report  \
# count   100000.000000  100000  100000  100000         100000
# unique            NaN      10      38       8              2
# top               NaN  Toyota  Seltos   Black            Yes
# freq              NaN   10138    3389   12597          50098
# mean      2017.504000     NaN     NaN     NaN            NaN
# std          4.610574     NaN     NaN     NaN            NaN
# min       2010.000000     NaN     NaN     NaN            NaN
# 25%       2014.000000     NaN     NaN     NaN            NaN
# 50%       2018.000000     NaN     NaN     NaN            NaN
# 75%       2022.000000     NaN     NaN     NaN            NaN
# max       2025.000000     NaN     NaN     NaN            NaN
#
#         Initial_Odometer  Odometer_At_Incident
# count       100000.00000         100000.000000
# unique               NaN                   NaN
# top                  NaN                   NaN
# freq                 NaN                   NaN
# mean         62416.42008          69419.199970
# std          33295.18949          33428.992495
# min           5002.00000           7130.000000
# 25%          33521.00000          40534.750000
# 50%          62413.50000          69403.500000
# 75%          91322.50000          98370.250000
# max         120000.00000         131741.000000
#
# [11 rows x 26 columns]

# %% [markdown]
# # STEP:1 Missing Value Treatment

# %% [markdown]
# ### Identify Missing Value Patterns (MCAR, MAR, MNAR)

# %% [markdown]
# #### Check missing values

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Fraud_Ind                  0
# Policy_Start_Date          0
# Initial_Odometer           0
# Police_Report              0
# Color                      0
# Model                      0
# Make                       0
# Model_Year                 0
# Claim_Amount               0
# Claims_Status              0
# Commute_Discount           0
# Gender                     0
# Age                        0
# Date_At_Current_Address    0
# DL_Expiry_Date             0
# Drivers_License_State      0
# Drivers_License_Num        0
# License_Plate              0
# Claim_Num                  0
# Policy_Num                 0
# Driver_Num                 0
# Household_Num              0
# Claim_Initiated_Date       0
# Accident_Date              0
# Policy_Expiry_Date         0
# Odometer_At_Incident       0
# dtype: int64

# %% [markdown]
# #### Missing value percentage

# %%
(df.isnull().mean() * 100).sort_values(ascending=False)
# Out:
# Fraud_Ind                  0.0
# Policy_Start_Date          0.0
# Initial_Odometer           0.0
# Police_Report              0.0
# Color                      0.0
# Model                      0.0
# Make                       0.0
# Model_Year                 0.0
# Claim_Amount               0.0
# Claims_Status              0.0
# Commute_Discount           0.0
# Gender                     0.0
# Age                        0.0
# Date_At_Current_Address    0.0
# DL_Expiry_Date             0.0
# Drivers_License_State      0.0
# Drivers_License_Num        0.0
# License_Plate              0.0
# Claim_Num                  0.0
# Policy_Num                 0.0
# Driver_Num                 0.0
# Household_Num              0.0
# Claim_Initiated_Date       0.0
# Accident_Date              0.0
# Policy_Expiry_Date         0.0
# Odometer_At_Incident       0.0
# dtype: float64

# %% [markdown]
# ### Apply Imputation

# %% [markdown]
# #### Numerical → Median

# %%
num_cols = df.select_dtypes(include=['int64','float64']).columns

num_imputer = SimpleImputer(strategy='median')
df[num_cols] = num_imputer.fit_transform(df[num_cols])

# %% [markdown]
# #### Categorical → Mode

# %%
cat_cols = df.select_dtypes(include=['object']).columns

cat_imputer = SimpleImputer(strategy='most_frequent')
df[cat_cols] = cat_imputer.fit_transform(df[cat_cols])

# %% [markdown]
# # STEP 2: Outlier Detection & Treatment
# ## Detect Outliers (IQR Method)

# %%
def iqr_outliers(col):
    Q1 = col.quantile(0.25)
    Q3 = col.quantile(0.75)
    IQR = Q3 - Q1
    return col[(col < Q1 - 1.5*IQR) | (col > Q3 + 1.5*IQR)]

for col in num_cols:
    print(col, iqr_outliers(df[col]).shape[0])
# Out:
# Fraud_Ind 7407
# Household_Num 0
# Policy_Num 0
# Age 0
# Commute_Discount 0
# Claims_Status 0
# Claim_Amount 0
# Model_Year 0
# Initial_Odometer 0
# Odometer_At_Incident 0

# %%
iso = IsolationForest(contamination=0.02, random_state=42)
outliers = iso.fit_predict(df[num_cols])

df['outlier_flag'] = outliers

# %%
for col in num_cols:
    lower = df[col].quantile(0.01)
    upper = df[col].quantile(0.99)
    df[col] = np.clip(df[col], lower, upper)

# %% [markdown]
# # STEP 3: Data Type & Format Standardization
# ## 1.Fix incorrect data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Fraud_Ind                100000 non-null  int64
#  1   Policy_Start_Date        100000 non-null  object
#  2   Policy_Expiry_Date       100000 non-null  object
#  3   Accident_Date            100000 non-null  object
#  4   Claim_Initiated_Date     100000 non-null  object
#  5   Household_Num            100000 non-null  float64
#  6   Driver_Num               100000 non-null  object
#  7   Policy_Num               100000 non-null  float64
#  8   Claim_Num                100000 non-null  object
#  9   License_Plate            100000 non-null  object
#  10  Drivers_License_Num      100000 non-null  object
#  11  Drivers_License_State    100000 non-null  object
#  12  DL_Expiry_Date           100000 non-null  object
#  13  Date_At_Current_Address  100000 non-null  object
#  14  Age                      100000 non-null  int64
#  15  Gender                   100000 non-null  object
#  16  Commute_Discount         100000 non-null  int64
#  17  Claims_Status            100000 non-null  int64
#  18  Claim_Amount             100000 non-null  int64
#  19  Model_Year               100000 non-null  int64
#  20  Make                     100000 non-null  object
#  21  Model                    100000 non-null  object
#  22  Color                    100000 non-null  object
#  23  Police_Report            100000 non-null  object
#  24  Initial_Odometer         100000 non-null  float64
#  25  Odometer_At_Incident     100000 non-null  float64
#  26  outlier_flag             100000 non-null  int64
# dtypes: float64(4), int64(7), object(16)
# memory usage: 20.6+ MB

# %% [markdown]
# ##  fraud_ind  should be int 0 or 1

# %%
df['Fraud_Ind'] = df['Fraud_Ind'].astype(int)

# %% [markdown]
# ## Convert dates

# %%
date_cols = [
    'Policy_Start_Date',
    'Policy_Expiry_Date',
    'Accident_Date',
    'Claim_Initiated_Date',
    'DL_Expiry_Date',
    'Date_At_Current_Address'
]

for col in date_cols:
    df[col] = pd.to_datetime(df[col], format='%m/%d/%Y', errors='coerce')

# %% [markdown]
# ## Fix ID columns

# %%
df['Household_Num'] = df['Household_Num'].astype(str)
df['Policy_Num'] = df['Policy_Num'].astype(str)

# %% [markdown]
# ## Fix binary flag

# %%
df['Commute_Discount'] = df['Commute_Discount'].astype(int)

# %% [markdown]
# ## Fix status column

# %%
df['Claims_Status'] = df['Claims_Status'].astype(str)

# %%
df['Police_Report'] = df['Police_Report'].map({'Yes': 1, 'No': 0})

# %%
categorical_cols = ['Gender','Claims_Status','Make','Model','Color','Drivers_License_State']
for col in categorical_cols:
    df[col] = df[col].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Fraud_Ind                98000 non-null  int64
#  1   Policy_Start_Date        98000 non-null  datetime64[ns]
#  2   Policy_Expiry_Date       98000 non-null  datetime64[ns]
#  3   Accident_Date            98000 non-null  datetime64[ns]
#  4   Claim_Initiated_Date     98000 non-null  datetime64[ns]
#  5   Household_Num            98000 non-null  float64
#  6   Driver_Num               98000 non-null  object
#  7   Policy_Num               98000 non-null  float64
#  8   Claim_Num                98000 non-null  object
#  9   License_Plate            98000 non-null  object
#  10  Drivers_License_Num      98000 non-null  object
#  11  Drivers_License_State    98000 non-null  category
#  12  DL_Expiry_Date           98000 non-null  datetime64[ns]
#  13  Date_At_Current_Address  98000 non-null  datetime64[ns]
#  14  Age                      98000 non-null  int64
#  15  Gender                   98000 non-null  category
#  16  Commute_Discount         98000 non-null  int64
#  17  Claims_Status            98000 non-null  category
#  18  Claim_Amount             98000 non-null  int64
#  19  Model_Year               98000 non-null  int64
#  20  Make                     98000 non-null  category
#  21  Model                    98000 non-null  category
#  22  Color                    98000 non-null  category
#  23  Police_Report            98000 non-null  object
#  24  Initial_Odometer         98000 non-null  float64
#  25  Odometer_At_Incident     98000 non-null  float64
#  26  outlier_flag             98000 non-null  int64
# dtypes: category(6), datetime64[ns](6), float64(4), int64(6), object(5)
# memory usage: 17.0+ MB

# %% [markdown]
# # STEP 4: Duplicate & Inconsistent Record Removal

# %% [markdown]
# ## Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Date Inconsistencies

# %% [markdown]
# ### Accident before policy start

# %%
df = df[df['Accident_Date'] >= df['Policy_Start_Date']]

# %% [markdown]
# ### Accident after policy expiry

# %%
df = df[df['Accident_Date'] <= df['Policy_Expiry_Date']]

# %% [markdown]
# ### Claim initiated before accident

# %%
df = df[df['Claim_Initiated_Date'] >= df['Accident_Date']]

# %% [markdown]
# ## Odometer Consistency

# %%
df = df[df['Odometer_At_Incident'] >= df['Initial_Odometer']]

# %% [markdown]
# ## Age Validity

# %%
df = df[(df['Age'] >= 16) & (df['Age'] <= 100)]

# %% [markdown]
# ## Claim Amount Validity

# %%
df = df[df['Claim_Amount'] > 0]

# %% [markdown]
# # STEP 5: Data Leakage Prevention

# %% [markdown]
# ### Drop Leakage & ID Columns

# %%
leakage_cols = [
    'Household_Num',
    'Driver_Num',
    'Policy_Num',
    'Claim_Num',
    'License_Plate',
    'Drivers_License_Num',
    'outlier_flag'
]

df_model = df.drop(columns=leakage_cols)

# %%
df.head()
# Out:
#    Fraud_Ind Policy_Start_Date Policy_Expiry_Date Accident_Date  \
# 0          0        2025-01-27         2025-07-28    2025-03-09
# 1          0        2025-06-01         2025-11-30    2025-06-04
# 2          0        2025-06-22         2025-12-21    2025-07-04
# 3          0        2025-01-02         2025-07-03    2025-01-27
# 4          0        2024-10-25         2025-04-25    2024-11-19
#
#   Claim_Initiated_Date  Household_Num Driver_Num   Policy_Num Claim_Num  \
# 0           2025-04-08   4.670185e+09   SW059585  355924169.0  DZW11767
# 1           2025-07-05   8.526792e+09   ZO779075  848558311.0  CVG38057
# 2           2025-07-06   4.618821e+09   LG406912  473829217.0  RUO86042
# 3           2025-02-27   3.846199e+09   NJ146743  116719734.0  WOS87550
# 4           2024-12-22   9.856771e+09   KX673536  481900450.0  ACJ85041
#
#   License_Plate  ... Claims_Status Claim_Amount Model_Year        Make  \
# 0      MGN62082  ...             1         3954       2022  Volkswagen
# 1      WXK26533  ...             4        17917       2011      Toyota
# 2      NNL54173  ...             3        13884       2015        Audi
# 3      THC81673  ...             3         4079       2015         BMW
# 4      NKY26268  ...             2         3671       2020       Honda
#
#       Model   Color  Police_Report  Initial_Odometer  Odometer_At_Incident  \
# 0     Jetta     Red             No           87817.0               93539.0
# 1     Camry    Grey            Yes           22928.0               30075.0
# 2        A6   Black             No           79831.0               91252.0
# 3  3 Series   White             No          112017.0              117688.0
# 4    Accord  Silver             No          101637.0              110535.0
#
#    outlier_flag
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
#
# [5 rows x 27 columns]

# %%
df.to_pickle('cleaned_data.pkl')

# %%
if 'outlier_flag' in df.columns:
    print(df['outlier_flag'].value_counts())
# Out:
# outlier_flag
#  1    96035
# -1     1965
# Name: count, dtype: int64

# %%
duplicates = df.duplicated().sum()
print("Number of duplicate rows:", duplicates)
# Out:
# Number of duplicate rows: 0

# %%
id_cols = ['Policy_Num','Claim_Num','Driver_Num']
for col in id_cols:
    print(col, "unique:", df[col].nunique(), "vs total rows:", len(df))
# Out:
# Policy_Num unique: 96045 vs total rows: 98000
# Claim_Num unique: 97995 vs total rows: 98000
# Driver_Num unique: 97992 vs total rows: 98000

# %%
# Accident_Date should not be after Claim_Initiated_Date
leak_check = df[df['Accident_Date'] > df['Claim_Initiated_Date']]
print("Rows violating date order (should be 0):", len(leak_check))
# Out:
# Rows violating date order (should be 0): 0

# %%
df.shape
# Out:
# (98000, 27)
